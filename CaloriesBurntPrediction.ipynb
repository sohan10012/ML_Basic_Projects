# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('/content/drive/MyDrive/Dataset/Copy of exercise.csv')
data2 = pd.read_csv('/content/drive/MyDrive/Dataset/Copy of calories.csv')
data.head()
data2.head()
# Out:
#     User_ID  Calories
# 0  14733363     231.0
# 1  14861698      66.0
# 2  11179863      26.0
# 3  16180408      71.0
# 4  17771927      35.0

# %%
data['calories'] = data2['Calories']

# %%
data.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
le = LabelEncoder()
data['Gender'] = le.fit_transform(data['Gender'])

# %%
data.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363       1   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698       0   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863       1   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408       0   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927       0   27   154.0    58.0      10.0        81.0       39.8
#
#    calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
data.isnull().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# calories      0
# dtype: int64

# %%
sc = StandardScaler()
X = data.drop('calories',axis=1)
Y = data['calories']
X = sc.fit_transform(X)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
model = XGBRegressor()
model.fit(X_train,Y_train)

predictiontrain  = model.predict(X_test)
accuracytrain = r2_score(Y_test,predictiontrain)
print('Train Accuracy :',accuracytrain)

predictiontest = model.predict(X_test)
accuracytest = r2_score(Y_test,predictiontest)
print('Test Accuracy :',accuracytest)
# Out:
# Train Accuracy : 0.9986806963430097
# Test Accuracy : 0.9986806963430097
